# %%
from dotenv import load_dotenv
import os
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-tiADwcR4xi2q

# %%
# memory = context

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chat.invoke("게는 누구의 후손이니?")
# Out:
# AIMessage(content='게는 고대 신화에서 바다 신 포세이돈과 그의 아내인 아메피트리티의 아들인 트리톤의 후손으로 믿어지고 있습니다. 그들은 바다와 바다 생물들을 통제하는 신들로 여겨지며, 그 후손들이 바다 생물 중 하나인 게로 알려져 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 20, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIsedPlnen8UT6WeOU2spJF5ORuX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f3-7234-7453-9cf6-913930257cb9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 114, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## ConversationBufferMemory

# %%
from langchain_classic.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()

# %%
memory.save_context(
    {"input": "hi"},
    {"output": "h r u"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': 'Human: hi\nAI: h r u'}

# %% [markdown]
# ## return_message = True
# - history객체에 AIMessage와 HumanMessage로 저장하게 만든다

# %%
memory = ConversationBufferMemory(return_messages=True)

# %%
memory.save_context(
    {"input": "hi"},
    {"output": "h r u"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content='h r u', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# ## 문제점
# : 문맥이 이어지지 않음

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chat.invoke("이름 알려줘")
# Out:
# AIMessage(content='죄송합니다, 제가 이름을 가지고 있지는 않습니다. 저는 인공지능 어시스턴트로 대화를 도와드리는 프로그램입니다. 어떤 도움이 필요하신가요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 15, 'total_tokens': 81, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUeKQyKZM3MvosfgWcUlH20ztDZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-6125-7be0-b4e5-903a2a596fab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 66, 'total_tokens': 81, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chat.invoke("")

# %% [markdown]
# ## 체인

# %%
from langchain_classic.chains import ConversationChain

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationBufferMemory(return_messages=True)

chain = ConversationChain(llm=llm, memory=memory)

# %%
result = chain.invoke("my name is ooo")

# %%
result
# Out:
# {'input': 'my name is ooo',
#  'history': [HumanMessage(content='my name is ooo', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="Hello ooo! It's nice to meet you. How can I assist you today?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'response': "Hello ooo! It's nice to meet you. How can I assist you today?"}

# %%
result["response"]
# Out:
# "Hello ooo! It's nice to meet you. How can I assist you today?"

# %%
result = chain.invoke("do you know my name?")

# %%
result["response"]
# Out:
# "Yes, your name is ooo. It's nice to have a conversation with you, ooo! How can I assist you today?"

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='my name is ooo', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello ooo! It's nice to meet you. How can I assist you today?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='do you know my name?', additional_kwargs={}, response_metadata={}), AIMessage(content="Yes, your name is ooo. It's nice to have a conversation with you, ooo! How can I assist you today?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
def print_memory():
    print(memory.load_memory_variables({}))

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='my name is ooo', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello ooo! It's nice to meet you. How can I assist you today?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='do you know my name?', additional_kwargs={}, response_metadata={}), AIMessage(content="Yes, your name is ooo. It's nice to have a conversation with you, ooo! How can I assist you today?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# ## ConversationBufferWindowMemory

# %%
from langchain_classic.memory import ConversationBufferWindowMemory

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

# %%
memory.save_context({"input": "1"}, {"output": "1"})
memory.save_context({"input": "2"}, {"output": "2"})
memory.save_context({"input": "3"}, {"output": "3"})
memory.save_context({"input": "4"}, {"output": "4"})
memory.save_context({"input": "5"}, {"output": "5"})
memory.save_context({"input": "6"}, {"output": "6"})

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='3', additional_kwargs={}, response_metadata={}), AIMessage(content='3', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='4', additional_kwargs={}, response_metadata={}), AIMessage(content='4', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='5', additional_kwargs={}, response_metadata={}), AIMessage(content='5', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='6', additional_kwargs={}, response_metadata={}), AIMessage(content='6', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

chain = ConversationChain(llm=llm, memory=memory)

# %%
chain.invoke("do you know my name?")
chain.invoke("my name is ooo!")
chain.invoke("how make pizza?")
chain.invoke("who are you?")
chain.invoke("where are you?")

chain.invoke("do you know my name? again?")
# Out:
# {'input': 'do you know my name?',
#  'history': [HumanMessage(content='my name is ooo!', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='Nice to meet you, Ooo! How can I assist you today?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='how make pizza?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='To make a pizza, you will need to start by preparing the dough. You can mix flour, water, yeast, salt, and olive oil together to form a dough. Let the dough rise for about an hour. Then, roll out the dough into a circle and add your desired toppings such as tomato sauce, cheese, and any other ingredients you like. Finally, bake the pizza in the oven at a high temperature until the crust is golden brown and the cheese is melted. Enjoy your homemade pizza!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
# ...

# %% [markdown]
# ## ConversationSummaryMemory
# : 요약본 만든다

# %%
from langchain_classic.memory import ConversationSummaryMemory

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryMemory(llm=llm)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24684\2812279859.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryMemory(llm=llm)

# %%
chain = ConversationChain(llm=llm, memory=memory)

# %%
chain.invoke("Kim Sook is a remarkable person.")
# Out:
# {'input': 'Kim Sook is a remarkable person.',
#  'history': '',
#  'response': 'Yes, Kim Sook is a South Korean comedian, television host, and actress known for her quick wit and comedic timing. She has appeared in numerous variety shows and sitcoms, gaining popularity for her unique sense of humor and relatable personality. Kim Sook is also known for her philanthropic work, supporting various charitable causes and using her platform to raise awareness for important issues.'}

# %%
chain.invoke("Song Eun-i is a remarkable entrepreneur.")
# Out:
# {'input': 'Song Eun-i is a remarkable entrepreneur.',
#  'history': 'The human mentions that Kim Sook is a remarkable person. The AI agrees, describing Kim Sook as a South Korean comedian, television host, and actress known for her quick wit, comedic timing, and philanthropic work.',
#  'response': 'Song Eun-i is actually a South Korean comedian and actress, known for her comedic talent and versatility in various entertainment programs. She is not specifically known as an entrepreneur, but she has achieved success in the entertainment industry through her hard work and dedication.'}

# %%
print_memory()
# Out:
# {'history': 'The human mentions that Kim Sook is a remarkable person. The AI agrees, describing Kim Sook as a South Korean comedian, television host, and actress known for her quick wit, comedic timing, and philanthropic work. The human then brings up Song Eun-i as a remarkable entrepreneur, but the AI clarifies that Song Eun-i is a South Korean comedian and actress known for her comedic talent and versatility in various entertainment programs, rather than being specifically known as an entrepreneur.'}

# %%
chain.invoke("so how about Kim Sook??")
# Out:
# {'input': 'so how about Kim Sook??',
#  'history': 'The human mentions that Kim Sook is a remarkable person. The AI agrees, describing Kim Sook as a South Korean comedian, television host, and actress known for her quick wit, comedic timing, and philanthropic work. The human then brings up Song Eun-i as a remarkable entrepreneur, but the AI clarifies that Song Eun-i is a South Korean comedian and actress known for her comedic talent and versatility in various entertainment programs, rather than being specifically known as an entrepreneur.',
#  'response': 'Kim Sook is a South Korean comedian, television host, and actress known for her quick wit, comedic timing, and philanthropic work. She has appeared in numerous variety shows and sitcoms, showcasing her talent and charm to audiences. Kim Sook is also known for her work as a radio DJ and her advocacy for various social causes. She is truly a remarkable person in the entertainment industry.'}

# %% [markdown]
# ## ConversationSummaryBufferMemory
# : 요약본의 토큰 수를 제한하는 메모리

# %%
from langchain_classic.memory import ConversationSummaryBufferMemory

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryBufferMemory(
    llm=llm,
    return_messages=True,
    max_token_limit=50
)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24684\2114182186.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryBufferMemory(

# %%
chain = ConversationChain(llm=llm, memory=memory)

# %%
chain.invoke("so how about Song Eun-i as an entrepreneur?")
# Out:
# {'input': 'so how about Song Eun-i as an entrepreneur?',
#  'history': [],
#  'response': "Song Eun-i is a South Korean entrepreneur known for founding the popular beauty brand, Memebox. She started the company in 2012 and quickly grew it into a successful e-commerce platform for Korean beauty products. Eun-i's background in finance and her passion for beauty products helped her create a unique business model that resonated with consumers both in Korea and internationally. She has been recognized for her innovative approach to the beauty industry and has become a role model for aspiring entrepreneurs in South Korea."}

# %%
chain.invoke("so how about Kim Sook's career?")
# Out:
# {'input': "so how about Kim Sook's career?",
#  'history': [SystemMessage(content="The human asks about Song Eun-i as an entrepreneur. The AI explains that Song Eun-i is a South Korean entrepreneur known for founding the beauty brand, Memebox, in 2012. Eun-i's background in finance and passion for beauty products helped her create a successful e-commerce platform for Korean beauty products, making her a role model for aspiring entrepreneurs in South Korea.", additional_kwargs={}, response_metadata={})],
# ...

# %%
print_memory()
# Out:
# {'history': [SystemMessage(content="The human asks about Song Eun-i as an entrepreneur. The AI explains that Song Eun-i is a South Korean entrepreneur known for founding the beauty brand, Memebox, in 2012. Eun-i's background in finance and passion for beauty products helped her create a successful e-commerce platform for Korean beauty products, making her a role model for aspiring entrepreneurs in South Korea. The human then inquires about Kim Sook's career. The AI describes Kim Sook as a South Korean comedian, actress, and television personality who began her career in the entertainment industry as a comedian. Kim Sook gained popularity for her comedic talents and has showcased her versatility in various variety shows, sitcoms, and films. Known for her quick wit, humor, and ability to connect with audiences, Kim Sook remains a prominent figure in the South Korean entertainment scene with a successful career spanning many years.", additional_kwargs={}, response_metadata={})]}

# %% [markdown]
# ## ConversationKGMemory

# %%
from langchain_community.memory.kg import ConversationKGMemory

# %%
memory = ConversationKGMemory(return_messages=True, llm=llm)

# %%
chain = ConversationChain(llm=llm, memory=memory)

# %%
chain.invoke("you know Tim Hortons?")

chain.invoke("I like icecap!!")
chain.invoke("what is your favorit??")
chain.invoke("so What did I say my favorite thing was?")
# Out:
# {'input': 'so What did I say my favorite thing was?',
#  'history': [SystemMessage(content='On Tim Hortons: Tim Hortons is a popular Canadian coffee and fast food restaurant chain. Tim Hortons founded by Tim Horton. Tim Hortons founded in 1964. Tim Hortons has over 4,800 locations worldwide. Tim Hortons has a strong presence in Canada and the United States. Tim Hortons known for "Double Double" coffee. Tim Hortons is a popular Canadian coffee and fast food restaurant chain. Tim Hortons has a strong presence in Canada. Tim Hortons has a strong presence in United States.', additional_kwargs={}, response_metadata={})],
#  'response': "I'm sorry, I do not have that information."}

# %%
memory.load_memory_variables({})

# %%
chain.invoke("my hobby is rest")

chain.invoke("I like icecap!!")
chain.invoke("what is your favorit??")
chain.invoke("so What did I say my favorite thing was?")
# Out:
# {'input': 'so What did I say my favorite thing was?',
#  'history': [],
#  'response': "You said your favorite thing was hiking in the mountains and taking in the fresh air and beautiful scenery. It's a great way for you to relax and recharge."}

# %% [markdown]
# ## LCEL 방법 권장(v1이상 권장)

# %%
# MessagesPlaceholder: 프롬프트 안에 “대화 기록”을 끼워 넣는 자리표시 역할
# InMemoryChatMessageHistory: 대화 내용을 메모리에 저장
# RunnableWithMessageHistory: 체인 + 메모리 + 프롬프트를 자동으로 연결해주는 랩퍼

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """
        휴먼을 도와주는 AI 도구입니다. 친절하게 답변하세요.
    """),
    # MessagesPlaceholder / 저장소 메모리 위치
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}"),
])

# %%
chain = prompt | chat

# %% [markdown]
# ## 저장소 메모리 (Memory) 생성

# %%
# redis, db
store = {}

def get_history(session_id):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history"
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "my name is ooo!"
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
print(store["user1"])
# Out:
# Human: my name is ooo!
# AI: Hello ooo! How can I assist you today?
# Human: my name is ooo!
# AI: Hello ooo! How can I assist you today?
