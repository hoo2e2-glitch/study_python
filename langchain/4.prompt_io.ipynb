# %% [markdown]
# ## 프롬프트 저장, 불러오기

# %%
# json()

# %%
import os

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-tiADwcR4xi2q

# %%
base_path = r"D:\back_0900_phy\python\resource"

# %%
base_path
# Out:
# 'D:\\back_0900_phy\\python\\resource'

# %%
file_path = os.path.join(base_path, "prompt.json()")

# %%
file_path
# Out:
# 'D:\\back_0900_phy\\python\\resource\\prompt.json()'

# %%
with open(file_path, "w") as f:
    f.write("""
        {
            "_type": "prompt",
            "template": "{country}에 대해서 어떻게 생각함?",
            "input_variables": ["country"]
        
        }
    """)

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import load_prompt

# %%
chat = ChatOpenAI(temperature=0)

# %%
prompt = load_prompt(file_path)

# %%
chain = prompt | chat

# %%
result = chain.invoke({"country": "짐바브웨"})

# %% [markdown]
# ## YAML 파일

# %%
file_path = os.path.join(base_path, "prompt02.yaml")

# %%
file_path
# Out:
# 'D:\\back_0900_phy\\python\\resource\\prompt02.yaml'

# %%
with open(file_path, "w") as f:
    f.write("""
"_type": "prompt"
"template": "{country}에서 가장 유명한 음식이 어떤건가요??"
"input_variables": ["country"]
    """)

# %%
from langchain_core.prompts import PromptTemplate

# %%
load_prompt(file_path)
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}에서 가장 유명한 음식이 어떤건가요??')

# %%
prompt = load_prompt(file_path)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}에서 가장 유명한 음식이 어떤건가요??')

# %%
chain = prompt | chat

# %%
result = chain.invoke({"country": "일본"})

# %%
result = chain.invoke({""})
