# %%
# name: 주소호출
name = "홍길동"

# %%
name
# Out:
# '홍길동'

# %%
# 원시타입의 참조 주소가 바뀜
name = "장보고"

# %%
print(name)
# Out:
# 장보고

# %%
age = 20

# %%
print(name + 20)
#  1. 장보고20 -> js 처럼 자동형변환 불가
#  2. None
#  3. 오류 -> type error : int + string

# %%
# 숫자로 시작하면 안됨
123name = "홍길동"
# Out:
#   Cell In[7], line 2
#     123name = "홍길동"
#       ^
# SyntaxError: invalid decimal literal

# %%
# 특수문자는 _만 사용가능
!@name = '홍길동'
# Out:
# 'name'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
_name = "홍길동"

# %%
# 카멜 표기법 사용 불가
nAme = "홍길동"

# %%
# 공백문자 사용불가능
na me = "홍길동"

# %%
# 한글 변수명 사용불가능
이름 = "홍길동"

# %%
# 스네이크 표기법 - 사용
my_aame = "홍길동"
