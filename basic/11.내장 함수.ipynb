# %%
# 65 -> "A"
chr(65)

# "A" -> 65
ord("A")
# Out:
# 65

# %%
password = "test123"

for i in password:
    print(chr(ord(i) * 5000), end="")
# Out:
# 򍦠񻒨򌘘򍦠𻴈𽂐𾐘

# %%
expression = input("수식 입력.\nex 10*10\n")
# Out:
# 수식 입력.
# ex 10*10
#  10*10

# %%
eval(expression)
# Out:
# 100

# %%
print(format(1000000, ","))
print(format(1000000, "_"))
# Out:
# 1,000,000
# 1_000_000

# %%
# 튜플로 묶임
divmod(10, 2)
# Out:
# (5, 0)

# %%
# 오사오입
# 값이 1~4까지일때 버림
# 값이 5일때
# 앞 자리가 홀수면 반올림
# 앞 자리가 짝수면 버림

print(round(1.5))
print(round(2.5))
print(round(3.5))
print(round(4.5))
# Out:
# 2

# %% [markdown]
# ## 문자열 함수

# %%
# count

print("abcde".count("a"))

# %%
# find

# 첫번째 e의 인덱스 번호
print("abeeeeeeeeeecde".find("e"))

# %%
# 마지막 e의 인덱스 번호
print("abeeeeeeeeeecde".rfind("e"))

# %%
"a".upper()
# Out:
# 'A'

# %%
"a".lower()
# Out:
# 'a'

# %%
# 파스칼 표기법

"apple".capitalize()
# Out:
# 'Apple'

# %%
# join()
# 문자열, 리스트

print("a".join("b"))
print("a".join("b"))
# Out:
# b

# %%
li4 = [str((i + 1) * 10 for i in range(5))]

# %%
li4
# Out:
# ['<generator object <genexpr> at 0x000002A4BFE37E00>']

# %%
", ".join(li4)
# Out:
# '<generator object <genexpr> at 0x000002A4BFE37E00>'

# %%
str1 = "life is to short"

# %%
# 2. 값이 바뀌면 새롭게 반환
# 새로운 문자열 리턴

str1.replace("short", "Long")
# Out:
# 'life is to Long'

# %%
str1
# Out:
# 'life is to short'

# %%
# 문자열 내부의 값이 정수로만 이루어져있는지 확인 -> bool
"10".isdigit()
# Out:
# True

# %%
"10r".isdigit()
# Out:
# False

# %%
num1 = input("정수입력")
# Out:
# 정수입력 정수

# %%
if num1.isdigit():
    num1 = int(num1)
else:
    print("아님")
# Out:
# 아님

# %%
# 문자가 포함되었는지 확인하는 메서드

num1.isalpha()
# Out:
# True

# %%
data3 = "****************************da****************da****"

# %%
print(data3.replace("*", ""))

# %%
data3.lstrip("*")

# %%
data3.strip("*")

# %%
data3.rstrip("*")

# %%
"1564543121561515615.1616516.156".split(".")
# Out:
# ['1564543121561515615', '1616516', '156']

# %%
names = "짱구", "나", "수지"
score = 20, 50, 60
address = "떡잎마을", "강남", "압구정"

# %%
for i in zip(names, score, address):
    print(i)
# Out:
# ('짱구', 20, '떡잎마을')
# ('나', 50, '강남')
# ('수지', 60, '압구정')
