# %% [markdown]
# # 컬렉션(list, tuple, set, dict)
#
# 1. list []
#     - 추가, 수정, 삭제 언제나 가능
#     - [] 대괄호로 묶어주고 ,(콤마)로 값을 구분한다
#
# 2. tuple ()
#    - 한 번 생성되고나면 변경이 불가능
#    - () 소괄호로 묶어주고 ,(콤마)로 값을 구분한다
#
# 3. set {}
#    - 순서가 없는 자료 구조(비시퀀스)
#    - 중복된 값을 저장이 불가능
#    - {} 중괄호로 묶어주고 ,(콤마)로 값을 구분한다
#
# 4. dict {key:value}
#    - 키 + 값이 한 쌍으로 관리하며 ,(콤마)로 값을 구분한다
#    - key는 중복 값을 허용하지 않으며, value는 중복값을 허용한다
#    - key를 통해 value를 가져온다

# %%
li1 = []
li2 = list()

# %%
li2
# Out:
# []

# %%
# 시퀀스 자료구조

li3 = [10,20,30,40,50]
li4 = [100,200,300,400,500]

# %%
print(li3)
print(li4)
# Out:
# [10, 20, 30, 40, 50]
# [100, 200, 300, 400, 500]

# %%
li3 + li4
li3 * 2
# Out:
# [10, 20, 30, 40, 50, 10, 20, 30, 40, 50]

# %%
num = 10, 20, 30, 40

# %%
# tuple
# 튜플(packing)

num
# Out:
# (10, 20, 30, 40)

# %%
# unpacking

one, two, three, four = num
one, two, three, four = (10, 20, 30, 40)

# %%
one
two
# Out:
# 10

# %%
str1 = ['a', 'b', 'c', 'd']

# %%
# 멤버쉽 연산자(in): 포함했다면 True, 아니라면 False
'd' in str1
# Out:
# True

# %%
"실수" if "."

# %%
str2 = "abcdef"

# %%
str5 = ['a', 'b', 'c', 'd']

# 참조 주소가 바뀜
str5[0] = 'A'
print(str5)
# Out:
# ['A', 'b', 'c', 'd']

# %%
# 튜플은 수정이 불가능

tu1 = 'a', 'b', 'c'
tu1 = list()
tu1[0] = 'A'

print(tu1[0])

# %%
names = '장', '홍'

# %%
names * 2
# Out:
# ('장', '홍', '장', '홍')

# %%
name = ['장' + '홍']

# %%
# 튜플끼리 연결은 새로운 튜플이 생성됨
name2 = '이' , '김'

# %%
names + name2
# Out:
# ('장', '홍', '이', '김')

# %%
# 인코딩 순서대로
# 순서없음

set1 = {'a', 'b', 'c'}
set1 = {'박', '이', '김'}

# %%
set1
# set1 + {'김'} -> 안됨
# Out:
# {'김', '박', '이'}

# %% [markdown]
# ## *딕셔너리

# %%
# {} : dict
set1 = set()
di1 = {}

# %%
print(type(set1))
print(type(di1))
# Out:
# <class 'set'>
# <class 'dict'>

# %%
#  

di2 = {
    
    "a" : "apple",
    "b" : "banana",
    "c" : "cherry",
    "a" : "apple2"
}

# %%
di2
# Out:
# {'a': 'apple2', 'b': 'banana', 'c': 'cherry'}

# %%
a = 'a'
di2[a]

di2.get('b')
# Out:
# 'banana'

# %%
# di2["d"]

# 권장
di2.get('d', "없음(초기값)")

# %%
print(di2.keys())
print(di2.values())
print(di2.items()) #튜플

print(type(di2.keys()))
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_values(['apple2', 'banana', 'cherry'])
# dict_items([('a', 'apple2'), ('b', 'banana'), ('c', 'cherry')])
# <class 'dict_keys'>
