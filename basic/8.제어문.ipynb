# %%
score = int(input("점수입력"))
# Out:
# 점수입력 40

# %%
grade = ''

if score > 90:
    grade = 'A'
elif score > 80:
    grade = 'B'
elif score > 70:
    grade = 'C'
elif:
    grade = 'F'

print(grade)
# Out:
#   Cell In[5], line 9
#     elif
#         ^
# SyntaxError: invalid syntax
