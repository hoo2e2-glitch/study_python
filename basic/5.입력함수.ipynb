# %%
# input() -> .nextln()과 같은거

# 문자열
input()

# input = input() -> type error
# Out:
#  안녕
# '안녕'

# %%
name = input("이름 입력하기")
# Out:
# 이름 입력하기 홍길동

# %%
print(name)
# Out:
# 홍길동

# %%
# 두 수를 입력하고 그 결과를 더해서 출력

# %%
nem1 = input("첫번째 정수입력")
nem2 = input("두번째 정수입력")
# Out:
# 첫번째 정수입력 50
# 두번째 정수입력 40

# %%
# 연결-> 연산
result = int(nem1) + int(nem2)
print(f"{result}")
